# %% [markdown]
# ## ETL Process for obtaining a clean database

# %%
import pandas as pd
import numpy as np

import re
import unicodedata

# %%
TMDB_Data = pd.read_csv('TMDB_movie_dataset_v11.csv')

# %%
TMDB_Data.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
# Null data in title, release date, backdrop path, homepage, imdb_id, original_title, overview, poster_path, tagline, genres, production companies, production countries, spoken language, keywords
TMDB_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1289061 entries, 0 to 1289060
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1289061 non-null  int64
#  1   title                 1289046 non-null  object
#  2   vote_average          1289061 non-null  float64
#  3   vote_count            1289061 non-null  int64
#  4   status                1289061 non-null  object
#  5   release_date          1035149 non-null  object
#  6   revenue               1289061 non-null  int64
#  7   runtime               1289061 non-null  int64
#  8   adult                 1289061 non-null  bool
#  9   backdrop_path         330482 non-null   object
#  10  budget                1289061 non-null  int64
#  11  homepage              134319 non-null   object
#  12  imdb_id               638723 non-null   object
#  13  original_language     1289061 non-null  object
#  14  original_title        1289046 non-null  object
#  15  overview              1005135 non-null  object
#  16  popularity            1289061 non-null  float64
#  17  poster_path           853811 non-null   object
#  18  tagline               179989 non-null   object
#  19  genres                742650 non-null   object
#  20  production_companies  563707 non-null   object
#  21  production_countries  686399 non-null   object
#  22  spoken_languages      710189 non-null   object
#  23  keywords              331060 non-null   object
# dtypes: bool(1), float64(2), int64(5), object(16)
# memory usage: 227.4+ MB

# %%
# Checking the titles, as there are no info about title or original title, the rows are useless and are deleted.  
# #TMDB_Data[TMDB_Data['title'].isnull()]

TMDB_Data = TMDB_Data.dropna(subset = ['title'])
TMDB_Data = TMDB_Data.dropna(subset = ['original_title'] )
TMDB_Data = TMDB_Data.dropna(subset = ['release_date'] )

# %%
TMDB_Data["release_date"] = TMDB_Data["release_date"].str[:4]

# %%
TMDB_Data["release_date"]= TMDB_Data["release_date"].astype(int)
TMDB_Data = TMDB_Data[TMDB_Data['release_date'] <= 2025]

# %%
# The recommendation system will be based on the movies currently released. The ones in production, planned, rumored or cancelled will be excluded.
print(TMDB_Data['status'].unique())
TMDB_Data = TMDB_Data[TMDB_Data['status'] == 'Released']
# Out:
# ['Released' 'Planned' 'In Production' 'Post Production' 'Rumored'
#  'Canceled']

# %%
# Poster path is irrelevant to the recommendation system. Same for backdrop path and others. That columns are deleted.
columns_to_remove = ['poster_path', 'backdrop_path', 'id','status', 'homepage', 'title', 'tagline']

for column in columns_to_remove:
    try:
        TMDB_Data = TMDB_Data.drop(columns=column)
    except:
        pass

# %%
TMDB_Data
# Out:
#          vote_average  vote_count  release_date     revenue  runtime  adult  \
# 0               8.364       34495          2010   825532764      148  False
# 1               8.417       32571          2014   701729206      169  False
# 2               8.512       30619          2008  1004558444      152  False
# 3               7.573       29815          2009  2923706026      162  False
# 4               7.710       29166          2012  1518815515      143  False
# ...               ...         ...           ...         ...      ...    ...
# 1289054         0.000           0          1991           0        1  False
# 1289055         0.000           0          1995           0        3  False
# 1289056         0.000           0          2021           0        0  False
# 1289058         0.000           0          2018           0        4  False
# 1289059         0.000           0          2020           0       30  False
#
#             budget    imdb_id original_language               original_title  \
# 0        160000000  tt1375666                en                    Inception
# 1        165000000  tt0816692                en                 Interstellar
# 2        185000000  tt0468569                en              The Dark Knight
# 3        237000000  tt0499549                en                       Avatar
# 4        220000000  tt0848228                en                 The Avengers
# ...            ...        ...               ...                          ...
# 1289054          0        NaN                en                   Lawn Butch
# 1289055          0        NaN                en  Lessons In Baby Dyke Theory
# 1289056          0        NaN                en               La Falsa Noche
# 1289058          0        NaN                en                Blade Brigade
# 1289059          0        NaN                de                 Heisser Sand
#
#                                                   overview  popularity  \
# 0        Cobb, a skilled thief who commits corporate es...      83.952
# 1        The adventures of a group of explorers who mak...     140.241
# 2        Batman raises the stakes in his war on crime. ...     130.643
# 3        In the 22nd century, a paraplegic Marine is di...      79.932
# 4        When an unexpected enemy emerges and threatens...      98.082
# ...                                                    ...         ...
# 1289054  Being a codependent doesn't mean you can't tri...       0.600
# 1289055  In 1995 when Thirza Cuthand was 16 she felt li...       0.600
# 1289056                                                NaN       0.600
# 1289058  Blades has to defeat his ex rival Ajax for the...       0.600
# 1289059  Juan and Regina dream of their freedom. Is Ame...       0.600
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1289054                                          NaN
# 1289055                                       Comedy
# 1289056                                          NaN
# 1289058                      Comedy, Action, Western
# 1289059                               Romance, Drama
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1289054                                                NaN
# 1289055                                                NaN
# 1289056                                                NaN
# 1289058                                       Cult Classic
# 1289059                                        B. S. Video
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1289054                  United States of America
# 1289055                                    Canada
# 1289056                                       NaN
# 1289058                  United States of America
# 1289059                                   Germany
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1289054                                 NaN
# 1289055                                 NaN
# 1289056                                 NaN
# 1289058                             English
# 1289059                              German
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1289054                                                NaN
# 1289055                                                NaN
# 1289056                                                NaN
# 1289058                                       rollerblades
# 1289059                                                NaN
#
# [1019644 rows x 17 columns]

# %%
TMDB_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1019644 entries, 0 to 1289059
# Data columns (total 17 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   vote_average          1019644 non-null  float64
#  1   vote_count            1019644 non-null  int64
#  2   release_date          1019644 non-null  int32
#  3   revenue               1019644 non-null  int64
#  4   runtime               1019644 non-null  int64
#  5   adult                 1019644 non-null  bool
#  6   budget                1019644 non-null  int64
#  7   imdb_id               572905 non-null   object
#  8   original_language     1019644 non-null  object
#  9   original_title        1019644 non-null  object
#  10  overview              839920 non-null   object
#  11  popularity            1019644 non-null  float64
#  12  genres                678311 non-null   object
#  13  production_companies  527071 non-null   object
#  14  production_countries  643714 non-null   object
#  15  spoken_languages      648021 non-null   object
#  16  keywords              305497 non-null   object
# dtypes: bool(1), float64(2), int32(1), int64(4), object(9)
# memory usage: 129.3+ MB

# %%
Numerical_colums = ['vote_average', 'vote_count', 'revenue', 'runtime', 'budget', 'popularity', 'release_date']
Text_columns = ['original_title','original_language', 'genres', 'production_companies', 'production_countries', 'spoken_languages', 'keywords']
# Bool columns = adult

# %%
TMDB_Data["original_title"] = TMDB_Data["original_title"] .str.strip()

# %%
TMDB_Data['original_title'] = TMDB_Data['original_title'].str.replace("_", "", regex=False)
TMDB_Data['original_title'] = TMDB_Data['original_title'].str.replace(r'\s*:{2,}\s*', ':', regex=True)
TMDB_Data['original_title'] = TMDB_Data['original_title'].str.replace(r'\s*\+{2,}\s*', '+', regex=True)

# %%
# Text_columns = ['original_title', 'genres', 'production_companies', 'keywords']

# Preprocessing for text columns. 
for column in Text_columns:
    TMDB_Data[column] = TMDB_Data[column].fillna("")
    TMDB_Data[column] = TMDB_Data[column].str.replace(r'[^\w\s%&#$+<=>^:]', "", regex = True).str.strip()

# %%
def clean_html_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize_text(text):
    return unicodedata.normalize('NFKC', text)

# %%
TMDB_Data.loc[:,'original_title'] = TMDB_Data.loc[:,'original_title'].apply(normalize_text)
TMDB_Data.loc[:,'original_title'] = TMDB_Data.loc[:,'original_title'].apply(clean_html_tags)

# %%
TMDB_Data["original_title"] = TMDB_Data["original_title"] .str.strip()

# %%
pattern = r'^[^\s]{1}$' 
TMDB_Data = TMDB_Data[~TMDB_Data['original_title'].str.fullmatch(pattern)]
TMDB_Data = TMDB_Data[~TMDB_Data['original_title'].isin(['', 'Untitled', '0'])]

# %%
TMDB_Data['original_title'].sort_values(ascending = True).head(40)
# Out:
# 1177439                                                 # 32
# 1249724                                          #0 sisocisP
# 1093649                                                 #001
# 1093650                                                 #002
# 1093651                                                 #003
# 1270203                                                 #004
# 1232903                                                 #005
# 1093331                                                 #006
# 438283                                                  #007
# 538545                                                  #008
# 760187                                                  #009
# 582186                                      #01 Hygienikerin
# 38118                                                     #1
# 179691                                                    #1
# 146755                                                    #1
# 216823                                                    #1
# 588501                                            #1 Bad Dad
# 20152                                    #1 Cheerleader Camp
# 142347                                #1 Fan: A Darkomentary
# 367025               #1 Top Selling Best Comedy Special Ever
# 370824               #1 Top Selling Best Comedy Special Ever
# 705877                                   #1 Trump Fan in NYC
# 1004084                                     #11 Marey  Moiré
# 415137     #12019 คอนเสรต SINGING BIRD Concert By Request...
# 1074208                                           #132642667
# 337635              #13Noir  sobre cinema amores e tragédias
# 415133       #162009 คอนเสรต ธงไชย แฟนซ แฟนซน รองเตนเลนแตงตว
# 1193310                                                #1895
# 1244871                                           #1915House
# 445047                                                    #2
# 1016116                                                   #2
# 878469                                               #21xoxo
# 1018541                                 #233 Book of Mirrors
# 1266209                           #26 Containing Great Power
# 877741                                                   #27
# 908090                                                  #288
# 1126781                                                  #29
# 888791                                                    #3
# 1016114                                                   #3
# 1110575                                     #3 Normandy Lane
# Name: original_title, dtype: object

# %%
TMDB_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1018562 entries, 0 to 1289059
# Data columns (total 17 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   vote_average          1018562 non-null  float64
#  1   vote_count            1018562 non-null  int64
#  2   release_date          1018562 non-null  int32
#  3   revenue               1018562 non-null  int64
#  4   runtime               1018562 non-null  int64
#  5   adult                 1018562 non-null  bool
#  6   budget                1018562 non-null  int64
#  7   imdb_id               1018562 non-null  object
#  8   original_language     1018562 non-null  object
#  9   original_title        1018562 non-null  object
#  10  overview              838989 non-null   object
#  11  popularity            1018562 non-null  float64
#  12  genres                1018562 non-null  object
#  13  production_companies  1018562 non-null  object
#  14  production_countries  1018562 non-null  object
#  15  spoken_languages      1018562 non-null  object
#  16  keywords              1018562 non-null  object
# dtypes: bool(1), float64(2), int32(1), int64(4), object(9)
# memory usage: 129.2+ MB

# %%
# Manage NaN in imdb key column
TMDB_Data['imdb_id'].fillna('Unknown', inplace=True)
TMDB_Data['overview'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_15516\794917643.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMDB_Data['overview'].fillna('Unknown', inplace=True)

# %%
# TMDB_Data = TMDB_Data.drop_duplicates()

# %%
# TMDB_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1018348 entries, 0 to 1289059
# Data columns (total 17 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   vote_average          1018348 non-null  float64
#  1   vote_count            1018348 non-null  int64
#  2   release_date          1018348 non-null  int32
#  3   revenue               1018348 non-null  int64
#  4   runtime               1018348 non-null  int64
#  5   adult                 1018348 non-null  bool
#  6   budget                1018348 non-null  int64
#  7   imdb_id               1018348 non-null  object
#  8   original_language     1018348 non-null  object
#  9   original_title        1018348 non-null  object
#  10  overview              1018348 non-null  object
#  11  popularity            1018348 non-null  float64
#  12  genres                1018348 non-null  object
#  13  production_companies  1018348 non-null  object
#  14  production_countries  1018348 non-null  object
#  15  spoken_languages      1018348 non-null  object
#  16  keywords              1018348 non-null  object
# dtypes: bool(1), float64(2), int32(1), int64(4), object(9)
# memory usage: 129.2+ MB

# %%
# TMDB_Data[TMDB_Data['imdb_id'] == 'tt32094375']
# Out:
#         vote_average  vote_count  release_date  revenue  runtime  adult  \
# 197973           4.2           2          2024        0       92  False
# 199874           5.0           2          2024        0        0  False
# 228110           2.0           1          2024        0        0  False
# 235757           8.0           1          2024        0        0  False
# 249552           2.0           1          2024        0       92  False
# 255129           6.0           1          2024        0        0  False
# 267253           2.0           1          2024        0        0  False
# 300397           3.0           1          2024        0       92  False
#
#                         genres  \
# 197973
# 199874           Action Comedy
# 228110           Action Comedy
# 235757           Comedy Action
# 249552           Action Comedy
# 255129           Action Comedy
# 267253           Action Comedy
# 300397           Action Comedy
# 324786           Action Comedy
# 333482           Comedy Action
# 553958           Action Comedy
# 554867           Action Comedy
# 569391           Comedy Action
# 577749
# 585398           Action Comedy
# 588726
# 594191           Action Comedy
# 614649           Action Comedy
# 630404           Action Comedy
# 655704  Action Comedy Thriller
# 660670           Action Comedy
# 661577
# 667935           Action Comedy
# 668199
# 669350           Action Comedy
# 669981
# 677245           Action Comedy
# 685509           Comedy Action
# 689091
# 689526           Action Comedy
# 689792           Action Comedy
# 692306                  Action
# 693804           Action Comedy
# 698129           Action Comedy
# 698815           Action Comedy
# 737739                  Comedy
# 750209
# 753153           Action Comedy
# 758610           Action Comedy
# 769898           Action Comedy
# 779571           Action Comedy
# 785807           Comedy Action
# 800436           Action Comedy
#
#                                      production_companies  \
# 197973                               HartBeat Productions
# 199874
# 228110
# 235757
# 249552  HartBeat Productions Distribuidora: Amazon Pri...
# 255129
# 267253                               HartBeat Productions
# 300397                               HartBeat Productions
# 324786
# 333482                               HartBeat Productions
# 553958                               HartBeat Productions
# 554867                               HartBeat Productions
# 569391
# 577749
# 585398
# 588726                               HartBeat Productions
# 594191
# 614649
# 630404                               HartBeat Productions
# 655704
# 660670                               HartBeat Productions
# 661577
# 667935                              HeartBeat Productions
# 668199
# 669350
# 669981
# 677245
# 685509
# 689091
# 689526
# 689792                               HartBeat Productions
# 692306
# 693804                               HartBeat Productions
# 698129
# 698815                               HartBeat Productions
# 737739
# 750209
# 753153                                       Hartbeat LLC
# 758610
# 769898                               HartBeat Productions
# 779571
# 785807                                             Amazon
# 800436                                       Hartbeat LLC
#
#             production_countries spoken_languages  \
# 197973  United States of America          English
# 199874                                    English
# 228110
# 235757  United States of America
# 249552                                    English
# 255129                                    English
# 267253
# 300397  United States of America          English
# 324786                                     German
# 333482
# 553958  United States of America          English
# 554867  United States of America
# 569391                                    English
# 577749
# 585398                                     German
# 588726  United States of America          English
# 594191                                    English
# 614649                             German English
# 630404  United States of America
# 655704                    Brazil       Portuguese
# 660670  United States of America          English
# 661577
# 667935  United States of America
# 668199                                    English
# 669350
# 669981                                    English
# 677245                                    English
# 685509
# 689091  United States of America          English
# 689526
# 689792                                     French
# 692306                            Spanish English
# 693804
# 698129
# 698815  United States of America          English
# 737739                                    English
# 750209
# 753153  United States of America
# 758610
# 769898                                    English
# 779571                                    English
# 785807  United States of America          English
# 800436  United States of America          English
#
#                                                 keywords
# 197973
# 199874
# 228110
# 235757
# 249552
# 255129
# 267253
# 300397
# 324786
# 333482
# 553958
# 554867
# 569391
# 577749
# 585398  martial arts parody explosion film within a film
# 588726
# 594191
# 614649
# 630404
# 655704
# 660670
# 661577
# 667935
# 668199                                     action comedy
# 669350
# 669981
# 677245
# 685509
# 689091
# 689526
# 689792
# 692306
# 693804
# 698129
# 698815
# 737739
# 750209
# 753153
# 758610
# 769898
# 779571
# 785807
# 800436

# %%
# Remove duplicates in BOTH imdb ID's and original title

# TMDB_Data['original_title'].value_counts()
# Out:
# original_title
# Home                      90
# Alone                     66
# Carmen                    63
# Limbo                     55
# Solo                      50
#                           ..
# Trannymals Go To Court     1
# El Carbón Chileno          1
# The Theatre                1
# 埋もれる                       1
# Heisser Sand               1
# Name: count, Length: 908907, dtype: int64

# %%
# Cleaned database for storing in mySQL
# TMDB_Data.to_csv('TMDB_movie_dataset_cleaned.csv', index=False)

# %% [markdown]
# ## Vectorization with TF-IDF for textural features and standarization of numerical features

# %%
import scipy
from sklearn.preprocessing import MinMaxScaler

from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix

# %%
# Scaling for numerical columns
scaler = MinMaxScaler()
TMDB_Data[Numerical_colums] = scaler.fit_transform( TMDB_Data[Numerical_colums] )

# %%
# TF-IDF Vectorization for each column and posterior concatenation of all vectors.

tfidf_vectors = []

for col in Text_columns:

    scaler_text = TfidfVectorizer(max_features=50)
    X = scaler_text.fit_transform(TMDB_Data[col])

    tfidf_vectors.append(X)

X_combined = hstack(tfidf_vectors)

print('TF-IDF VECTOR SIZE: ', X_combined.shape)
# Out:
# TF-IDF VECTOR SIZE:  (1018562, 321)

# %%
dim1 = X_combined.shape[1]

# %%
X_num_sparse = scipy.sparse.csr_matrix(TMDB_Data[Numerical_colums].values)
X_num_sparse= X_num_sparse*np.sqrt(dim1/len(Numerical_colums)*0.3)
X_final = hstack([X_num_sparse, X_combined])

print('FINAL VECTOR SIZE: ', X_final.shape)
# Out:
# FINAL VECTOR SIZE:  (1018562, 328)

# %%
items = X_final.shape[0]
dim = X_final.shape[1]

# %% [markdown]
# ## ANN with faiss for recommendation system (content-based)

# %%
import faiss
from sklearn.preprocessing import normalize
from scipy.sparse import save_npz, load_npz

# %%
X_sparse = normalize(X_final, norm='l2', axis=1)

# %%
# Save the sparse matrix to a .npz file for storage and later use
# save_npz("X_sparse.npz", X_sparse)

# %%
query_idx = 26
movie = TMDB_Data.iloc[query_idx]['original_title']
print(f'Movie selected: {query_idx})', movie)
# Out:
# Movie selected: 26) Iron Man 3

# %%
index = faiss.IndexFlatL2(dim)
index.add(X_sparse.astype(np.float32).toarray())

# %%
xq = X_sparse[query_idx].reshape(1, -1).toarray().astype('float32')
Distances, Indexes = index.search(xq, k=6)  # 5 closer ANN

print("Indexes:", Indexes)
print("Distances:", Distances)
# Out:
# Indexes: [[26 52 42  6 12 40]]
# Distances: [[0.         0.05973065 0.06383241 0.06395502 0.07796714 0.07932597]]

# %%
print(f"Recommended movies since you've watched {movie} : ")

for i, idx in enumerate(Indexes[0]):
    if i > 0:
         print(f"{TMDB_Data.iloc[idx]['original_title']}")
# Out:
# Recommended movies since you've watched Iron Man 3 :
# AntMan
# Thor: Ragnarok
# Avengers: Infinity War
# Iron Man
# Iron Man 2
